# %%
#To create a program that gives different messages based on time of day
import datetime

def get_greeting():
    # Get the current time
    current_time = datetime.datetime.now()
    
    # Extract the hour (0-23)
    current_hour = current_time.hour
    
    # Determine the greeting based on the hour
    if 5 <= current_hour < 12:
        return "Good morning!"
    elif 12 <= current_hour < 17:
        return "Good afternoon!"
    elif 17 <= current_hour < 21:
        return "Good evening!"
    else:
        return "Good night!"

# Execute the function and print the result
message = get_greeting()
print(f"Current hour: {datetime.datetime.now().strftime('%H:%M')}")
print(message)

# %%
#Build a number guessing game using if-else statements
def guess_num(num,guess):
  if guess == num:
    print("Congratulations! You guessed the correct number.")
  elif guess < num:
    print("Too low! Try again.")
  else:
    print("Too High! Try again.")  
num = 25
guess = int(input("Guess a number between 1 and 50: "))
guess_num(num,guess)

# %%
#Use for loop to print numbers from 1 to 100
for i in range(1,101):
  print(i)

# %%
#Create a function that calculates area of rectangle
def area_of_rectangle(length,breath):
  area = length * breath
  print(f"The area of the rectangle is {area}")
length = int(input("Enter the length of the rectangle: "))
breath = int(input("Enter the breath of the rectangle: "))  
area_of_rectangle(length,breath)

# %%
#Make a simple calculator that can add, subtract, multiply, divide
def calculator(num1,num2,operation):
  if(operation == '+'):
    print(num1+num2)
  elif(operation == '-'):
    print(num1-num2)
  elif(operation == '*'):
    print(num1*num2)    
  elif(operation == '/'):
    print(num1/num2)  
  else:
    print("Invalid operation")
n1 = int(input("Give the first number: "))   
n2 = int(input("Give the second number: "))  
operator = input("Give the operation: ")
calculator(n1,n2,operator)
